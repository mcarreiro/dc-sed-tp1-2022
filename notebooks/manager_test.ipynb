# %%
from pathlib import Path

SED_HOME = Path.home().joinpath('Documents').joinpath('sed')
CDPP_DIR = SED_HOME.joinpath('CDPP')
CDPP_EXAMPLES = CDPP_DIR.joinpath('examples')
CDPP_SRC = CDPP_DIR.joinpath('src')
CDPP_SCRIPTS = CDPP_DIR.joinpath('scripts')
BASE_BIN = CDPP_SRC.joinpath('bin')
CDPP_ATOMICS = CDPP_SRC.joinpath('cd++/atomics')

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/dc-sed-tp1-2022/model/
#
# cat manager.ma
# Out:
# [top]
# components : manager@manager
# in : in_manager
# out : out1_manager out2_manager out3_manager out4_manager out5_manager out6_manager out7_manager out8_manager out9_manager out10_manager done_manager
# link : out1@manager out1_manager
# link : out2@manager out2_manager
# link : out3@manager out3_manager
# link : out4@manager out4_manager
# link : out5@manager out5_manager
# link : out6@manager out6_manager
# link : out7@manager out7_manager
# link : out8@manager out8_manager
# link : out9@manager out9_manager
# link : out10@manager out10_manager
# link : done@manager done_manager
# link : in_manager in@manager

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/dc-sed-tp1-2022/model/
# head manager.ev
# Out:
# 00:00:00:15 in_manager 1
# 00:00:00:30 in_manager 5
# 00:00:00:45 in_manager 10
# 00:00:01:20 in_manager 15
# 00:00:01:40 in_manager 20
# 00:00:03:10 in_manager 24
# 00:00:04:45 in_manager 25
# 00:03:08:45 in_manager 26

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/dc-sed-tp1-2022/src/
#
# make;
# Out:
# g++ -c -I../../../src/cd++/proc -I../../../src/cd++/proc/obj -I../../../src/cd++/proc/state -I../../../src/cd++/proc/state/obj -I../../../src/cd++/misc -I../../../src/cd++/misc/obj -I../../../src/cd++/misc/math -I../../../src/cd++/misc/math/obj -I../../../src/cd++/evt -I../../../src/cd++/evt/obj -I../../../src/cd++/msg -I../../../src/cd++/msg/obj -I../../../src/cd++/atomics -I../../../src/cd++/atomics/qss -I../../../src/cd++/atomics/qss/obj -I../../../src/cd++/atomics/cpu -I../../../src/cd++/atomics/cpu/obj -I../../../src/cd++/atomics/generator -I../../../src/cd++/atomics/generator/obj -I../../../src/cd++/atomics/queue -I../../../src/cd++/atomics/queue/obj -I../../../src/cd++/atomics/transducer -I../../../src/cd++/atomics/transducer/obj -I../../../src/cd++/utils -I../../../src/cd++/utils/obj -I../../../src/cd++/utils/log -I../../../src/cd++/utils/log/obj -I../../../src/cd++/parser -I../../../src/cd++/parser/cdlang -I../../../src/cd++/parser/cdlang/obj -I../../../src/cd++/parser/obj -I../../../src/cd++/cell -I../../../src/cd++/cell/obj -I../../../src/cd++/model -I../../../src/cd++/model/obj -I../../../src/cd++/model/state -I../../../src/cd++/model/state/obj -I../../../src/cd++/warped -I../../../src/cd++/warped/common -I../../../src/cd++/warped/common/obj -I../../../src/cd++/warped/notime -I../../../src/cd++/warped/notime/obj -I../../../src/cd++/main -I../../../src/cd++/main/obj -I../../../src/cd++/sim -I../../../src/cd++/sim/obj -I../../../src/cd++/sim/loader -I../../../src/cd++/sim/loader/obj -I../../../src/cd++/val -I../../../src/cd++/val/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  Manager.cpp -o /Users/mcarreiro/Documents/sed/CDPP/examples/dc-sed-tp1-2022/src/bin/Manager.o
# In file included from Manager.cpp:7:
# In file included from ../../../src/cd++/msg/message.h:29:
# In file included from ../../../src/cd++/sim/parsimu.h:24:
# In file included from ../../../src/cd++/warped/notime/LogicalProcess.h:31:
# ../../../src/cd++/warped/notime/CommManager.h:35:1: warning: class 'ObjectRecord' was previously declared as a struct; this is valid, but may result in linker errors under the Microsoft C++ ABI [-Wmismatched-tags]
# class ObjectRecord;
# ^
# ../../../src/cd++/warped/notime/ObjectRecord.h:32:8: note: previous use is here
# struct ObjectRecord {
#        ^
# ../../../src/cd++/warped/notime/CommManager.h:35:1: note: did you mean struct here?
# class ObjectRecord;
# ^~~~~
# struct
# Manager.cpp:36:2: warning: field 'in' will be initialized after field 'out1' [-Wreorder-ctor]
#         in(addInputPort( "in" )),
#         ^
# Manager.cpp:47:2: warning: field 'out10' will be initialized after field 'preparationTime' [-Wreorder-ctor]
#         out10(addOutputPort( "out10" )),
#         ^
# 3 warnings generated.
# /Library/Developer/CommandLineTools/usr/bin/make -C ../../../src/cd++ cd++ OUT_DIR=/Users/mcarreiro/Documents/sed/CDPP/examples/dc-sed-tp1-2022/src/bin MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C cpu OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C queue OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C qss OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C generator OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C transducer OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C math OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/model OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C state OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C cdlang OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# g++ -c -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  gram.c -o obj/gram.o
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C state OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make clean
# /Library/Developer/CommandLineTools/usr/bin/make -C loader clean OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# /Library/Developer/CommandLineTools/usr/bin/make -C loader OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# g++ -c -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  stdaload.cpp -o obj/stdaload.o
# In file included from stdaload.cpp:37:
# In file included from /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/LogicalProcess.h:31:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/CommManager.h:35:1: warning: class 'ObjectRecord' was previously declared as a struct; this is valid, but may result in linker errors under the Microsoft C++ ABI [-Wmismatched-tags]
# class ObjectRecord;
# ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/ObjectRecord.h:32:8: note: previous use is here
# struct ObjectRecord {
#        ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/CommManager.h:35:1: note: did you mean struct here?
# class ObjectRecord;
# ^~~~~
# struct
# 1 warning generated.
# g++ -c -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  parsimu.cpp -o obj/parsimu.o
# In file included from parsimu.cpp:18:
# In file included from /Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/parsimu.h:24:
# In file included from /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/LogicalProcess.h:31:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/CommManager.h:35:1: warning: class 'ObjectRecord' was previously declared as a struct; this is valid, but may result in linker errors under the Microsoft C++ ABI [-Wmismatched-tags]
# class ObjectRecord;
# ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/ObjectRecord.h:32:8: note: previous use is here
# struct ObjectRecord {
#        ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/CommManager.h:35:1: note: did you mean struct here?
# class ObjectRecord;
# ^~~~~
# struct
# In file included from parsimu.cpp:26:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/flatcoup.h:44:15: warning: 'FlatCoupledCell::createCells' hides overloaded virtual function [-Woverloaded-virtual]
#         CoupledCell &createCells( const CellPositionList &neighbors, const CellPositionList &selectList ) ;
#                      ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/coupcell.h:80:23: note: hidden overloaded virtual function 'CoupledCell::createCells' declared here: different number of parameters (3 vs 2)
#         virtual CoupledCell &createCells( const CellPositionList &neighbors, CellPartition *part, std::list<std::string> NCPorts );
#                              ^
# In file included from parsimu.cpp:26:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/flatcoup.h:46:15: warning: 'FlatCoupledCell::setCellValue' hides overloaded virtual function [-Woverloaded-virtual]
#         CoupledCell &setCellValue( const CellPosition &, const AbstractValue & ) ;
#                      ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/coupcell.h:82:23: note: hidden overloaded virtual function 'CoupledCell::setCellValue' declared here: different number of parameters (3 vs 2)
#         virtual CoupledCell &setCellValue( const CellPosition &, const std::string &, const Real & ) ;
#                              ^
# In file included from parsimu.cpp:27:
# In file included from /Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/tdcell.h:26:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/atomcell.h:52:7: warning: 'AtomicCellState::copyState' hides overloaded virtual function [-Woverloaded-virtual]
#         void copyState(AtomicCellState *);
#              ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/atomicstate.h:36:7: note: hidden overloaded virtual function 'AtomicState::copyState' declared here: type mismatch at 1st parameter ('BasicState *' vs 'AtomicCellState *')
#         void copyState(BasicState *);
#              ^
# parsimu.cpp:888:7: warning: comparison of array 'line' not equal to a null pointer is always true [-Wtautological-pointer-compare]
#                 if (line != NULL && (posi = strchr(line, '=')) != NULL)
#                     ^~~~    ~~~~
# parsimu.cpp:989:7: warning: comparison of array 'line' not equal to a null pointer is always true [-Wtautological-pointer-compare]
#                 if (line != NULL && (posi = strchr(line, '=')) != NULL)
#                     ^~~~    ~~~~
# 6 warnings generated.
# g++ -c -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/proc/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/misc/math/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/evt/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/msg/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/qss/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils/log/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/cdlang/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/parser/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/cell/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/common/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/main/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/loader/obj -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val -I/Users/mcarreiro/Documents/sed/CDPP/src/cd++/val/obj  -DREGISTER_ATOMICS -DKERNEL_NOTIME -DUSE_USER_VTIME -DHAS_BOOLEAN -g -O0 -Wall -Wno-deprecated -std=c++11  register.cpp -o obj/register.o
# In file included from register.cpp:15:
# In file included from /Users/mcarreiro/Documents/sed/CDPP/src/cd++/sim/parsimu.h:24:
# In file included from /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/LogicalProcess.h:31:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/CommManager.h:35:1: warning: class 'ObjectRecord' was previously declared as a struct; this is valid, but may result in linker errors under the Microsoft C++ ABI [-Wmismatched-tags]
# class ObjectRecord;
# ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/ObjectRecord.h:32:8: note: previous use is here
# struct ObjectRecord {
#        ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped/notime/CommManager.h:35:1: note: did you mean struct here?
# class ObjectRecord;
# ^~~~~
# struct
# In file included from register.cpp:18:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/cpu/cpu.h:41:7: warning: 'CPUState::copyState' hides overloaded virtual function [-Woverloaded-virtual]
#         void copyState(CPUState *);
#              ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/atomicstate.h:36:7: note: hidden overloaded virtual function 'AtomicState::copyState' declared here: type mismatch at 1st parameter ('BasicState *' vs 'CPUState *')
#         void copyState(BasicState *);
#              ^
# In file included from register.cpp:19:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/generator/generat.h:46:7: warning: 'GeneratorState::copyState' hides overloaded virtual function [-Woverloaded-virtual]
#         void copyState(GeneratorState *);
#              ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/atomicstate.h:36:7: note: hidden overloaded virtual function 'AtomicState::copyState' declared here: type mismatch at 1st parameter ('BasicState *' vs 'GeneratorState *')
#         void copyState(BasicState *);
#              ^
# In file included from register.cpp:20:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/queue/queue.h:41:7: warning: 'QueueState::copyState' hides overloaded virtual function [-Woverloaded-virtual]
#         void copyState(QueueState *);
#              ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/atomicstate.h:36:7: note: hidden overloaded virtual function 'AtomicState::copyState' declared here: type mismatch at 1st parameter ('BasicState *' vs 'QueueState *')
#         void copyState(BasicState *);
#              ^
# In file included from register.cpp:21:
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/atomics/transducer/transduc.h:43:7: warning: 'TransducerState::copyState' hides overloaded virtual function [-Woverloaded-virtual]
#         void copyState(TransducerState *);
#              ^
# /Users/mcarreiro/Documents/sed/CDPP/src/cd++/model/state/atomicstate.h:36:7: note: hidden overloaded virtual function 'AtomicState::copyState' declared here: type mismatch at 1st parameter ('BasicState *' vs 'TransducerState *')
#         void copyState(BasicState *);
#              ^
# 5 warnings generated.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/utils OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C log OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/val OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/main OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# make[2]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C /Users/mcarreiro/Documents/sed/CDPP/src/cd++/warped OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++ MODEL_FLAGS=-DREGISTER_ATOMICS
# /Library/Developer/CommandLineTools/usr/bin/make -C common OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# /Library/Developer/CommandLineTools/usr/bin/make -C notime OBJ_DIR=obj SRC_DIR=/Users/mcarreiro/Documents/sed/CDPP/src/cd++
# make[3]: Nothing to be done for `all'.
# g++ -L/Users/mcarreiro/Documents/sed/CDPP/examples/dc-sed-tp1-2022/src/bin -o /Users/mcarreiro/Documents/sed/CDPP/examples/dc-sed-tp1-2022/src/bin/cd++ main/obj/main.o warped/common/obj/VTime.o warped/notime/obj/CommManager.o warped/notime/obj/NoTimeObject.o warped/notime/obj/InputQueue.o warped/notime/obj/NoTime.o warped/notime/obj/DebugStream.o warped/notime/obj/BasicState.o warped/notime/obj/BasicNoTime.o warped/notime/obj/LogicalProcess.o warped/notime/obj/BasicEvent.o warped/notime/obj/Interactive.o warped/notime/obj/FileQueue.o warped/notime/obj/KernelMsgs.o /Users/mcarreiro/Documents/sed/CDPP/examples/dc-sed-tp1-2022/src/bin/Barrier.o /Users/mcarreiro/Documents/sed/CDPP/examples/dc-sed-tp1-2022/src/bin/Manager.o /Users/mcarreiro/Documents/sed/CDPP/examples/dc-sed-tp1-2022/src/bin/register.o -lsimu

# %%
# %%bash -s "$CDPP_EXAMPLES"
#
# cd $1/dc-sed-tp1-2022/src/
#
# bin/cd++ -m ../model/manager.ma  \
#          -e ../model/manager.ev  \
#          -l ../manager.log \
#          -o ../manager.out \
#          -t 01:00:00:00
# Out:
# PCD++: A Tool to Implement n-Dimensional Cell-DEVS models
# Version 3.0 - March 2003
# Troccoli A., Rodriguez D., Wainer G., Barylko A., Beyoglonian J., Lopez A.
# -----------------------------------------------------------------------------
# PCD++ Extended States: An extended and improved version of CD++ for Cell-DEVS
# Version 4.1.2 - December 2018
# Santi L., Castro, R., Pimás, J.
# -----------------------------------------------------------------------------
# Discrete Event Simulation Lab
# Departamento de Computación
# Facultad de Ciencias Exactas y Naturales
# Universidad de Buenos Aires, Argentina
# -----------------------------------------------------------------------------
# Compiled for standalone simulation
#
#
# Loading models from ../model/manager.ma
# Loading events from ../model/manager.ev
# Running parallel simulation. Reading models partition from
# Model partition details output to: /dev/null*
# Message log: ../manager.log
# Output to: ../manager.out
# Tolerance set to: 1e-08
# Configuration to show real numbers: Width = 12 - Precision = 5
# Quantum: Not used
# Evaluate Debug Mode = OFF
# Flat Cell Debug Mode = OFF
# Debug Cell Rules Mode = OFF
# Temporary File created by Preprocessor = /var/tmp/tmp.0.uWOso3
# Printing parser information = OFF
#
# Stop at time: 01:00:00:000:0
# LP 0: initializing simulation objects
# 00:00:00:015:0 / in_manager /      1.00000
# 00:00:00:030:0 / in_manager /      5.00000
# 00:00:00:045:0 / in_manager /     10.00000
# 00:00:01:020:0 / in_manager /     15.00000
# 00:00:01:040:0 / in_manager /     20.00000
# 00:00:03:010:0 / in_manager /     24.00000
# 00:00:04:045:0 / in_manager /     25.00000
# 00:03:08:045:0 / in_manager /     26.00000
# LP 0: starting simulation (NoTime).
# Simulation complete!
# Simulation ended!
# LP 0 has finished simulation
# At 00:03:08:046:0

# %% [markdown]
# # Resultados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# definimos los path a los archivos de interés
OUT_FILENAME = str(CDPP_EXAMPLES)+"/dc-sed-tp1-2022/manager.out"

# definimos los nombres de las columnas en los dataframes de pandas
TIME_COL = 'time'
PORT_COL = 'port'
VALUE_COL = 'value'

# conversion a floar
def parse_value(value: str):
    is_list = value.strip().startswith("[") and value.strip().endswith("]")
    if is_list:
        return tuple(float(num) for num in value.replace('[', '').replace(']', '').split(', '))
    return float(value)

# conversion VTime a float
def time_to_secs(time):
    h, m, s, ms, r = time.split(':')
    return float(h)*60*60. + float(m)*60. + float(s) + float(ms)/1000. + float(r)/1000.

# %%
df_converters = {
    VALUE_COL: parse_value,
    TIME_COL: time_to_secs
}

df_converters = {
    VALUE_COL: parse_value,
    TIME_COL: time_to_secs
}

salida = pd.read_csv(OUT_FILENAME,
                     delimiter=r'(?<!,)\s+',
                     engine='python',  # C engine doesnt work for regex
                     # Se puede usar esto para convertir los valores directamente:
                     converters=df_converters,
                     names=[TIME_COL, PORT_COL, VALUE_COL]
                    )
salida
# Out:
#       time           port   value
# 0  188.046   out1_manager  (0.0,)
# 1  188.046   out2_manager  (0.0,)
# 2  188.046   out3_manager  (0.0,)
# 3  188.046   out4_manager  (0.0,)
# 4  188.046   out5_manager  (0.0,)
# 5  188.046   out6_manager  (0.0,)
# 6  188.046   out7_manager  (0.0,)
# 7  188.046   out8_manager  (0.0,)
# 8  188.046   out9_manager  (0.0,)
# 9  188.046  out10_manager  (0.0,)
